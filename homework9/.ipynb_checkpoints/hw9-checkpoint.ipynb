# %% [markdown]
# # HW 9 - Introduction to Plotting
# ULAB - Physics and Astronomy Division \
# Due **Wednesday, November 13th, 2024 at 11:59pm** on Gradescope
#
# --------------------------------------------------------------
# ## Follow Good Coding Practices
# I will not include this information in the following questions, but if your functions/module/code does not have the following structure, you will get points taken off:
# - **Detailed** function and variable names.
# - A **comment** describing what the function is doing and what the inputs/outputs are (a comment randomly inside the function is not enough anymore).
# - A least one comment somewhere in the function describing an **important** line (this is subjective towards the programmer, but a line that someone reading your code might be confused about).
# - Different steps on different lines.
# - A `return` statement that only contains variables (so no print strings).
# - Import statements at the **top** of modules
# - Constants defined at the **top** of modules

# %% [markdown]
# # 1 Introduction to Plotting
# In this problem, we are going to break down the structure of `matplotlib.pyplot`.

# %%
# IMPORT NECESSARY PACKAGES
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# In a comment, write the code that would create a **new figure** where a plot or plots could be drawn. Make the `figsize` 5x5.

# %%
plt.figure(figsize = (5, 5))

# %% [markdown]
# In a comment, write the code that would make a variable called `x` such that it would contain the values [1, 2, 3, 4, 5] then write the code that would make a variable called `y` such that it would contain the values [2, 4, 6, 8, 10].

# %%
x = np.array([1, 2, 3, 4, 5])
y = np.array([2, 4, 6, 8, 10])

# %% [markdown]
# In a comment, write the code that would plot the data as a line **AND** write the code that would plot the data as points. Each of these should be separate lines.
#
# How would you change the color, linestyle/marker of your data? Choose a **color, linestyle** and **marker**, include this in the lines below.

# %%
plt.plot(x, y, color='green', linestyle='dashed', marker='*')
plt.scatter(x, y, color='red', linestyle='dotted', marker='s')

# %% [markdown]
# In a comment, write the code that would add a **title** to your plot. How would you adjust the fontsize?

# %%
plt.title('Graph', fontsize = 25)
# Out:
# Text(0.5, 1.0, 'Graph')

# %% [markdown]
# In a comment, write the code that would add a **label for the x-axis** and a **label for the y-axis**. How would you adjust the fontsize? Adjust the fontsize.

# %%
plt.xlabel('X Axis', fontsize = 10)
plt.ylabel('Y Axis', fontsize = 10)
# Out:
# Text(0, 0.5, 'Y Axis')

# %% [markdown]
# In a comment, write the code that would add a **legend** to your plot. This will be more than one line if your plotting cell above did not have a label.

# %%
plt.legend(['Plot', 'Scatter'])

# %% [markdown]
# In a comment, write the code that would **display** (show) the plot or figure you have just created.

# %%
plt.show()

# %% [markdown]
# Put all of you code together into **one function** in the cell below and **plot** the data. Add an **additional** feature to your plot that was not described above (i.e. adding a grid, you can do that but then you also have to come up with your own addition.)

# %%
def plottingDemo():
    x = np.array([1, 2, 3, 4, 5])
    y = np.array([2, 4, 6, 8, 10])
    plt.figure(figsize = (5, 5))
    plt.plot(x, y, color='green', linestyle='dashed', marker='*')
    plt.scatter(x, y, color='red', linestyle='dotted', marker='s')
    plt.title('Graph', fontsize = 25)
    plt.xlabel('X Axis', fontsize = 10)
    plt.ylabel('Y Axis', fontsize = 10)
    plt.legend(['Plot', 'Scatter'])
    plt.grid()
    return plt.show()

plottingDemo()

# %% [markdown]
# # 2 Plotting a Function
# Goal: Write a **function** that will plot $f(x) = x^2$ and $g(x) = \sqrt{x}$ on the same plot and return the $f(x)$ and $g(x)$ values as separate lists. Your plot needs to have the following:
# - An appropriate figure size (`figsize=(10,8)` is recommended)
# - Labeled x and y axis
# - A title
# - Different colors and linestyles for each function
# - A legend
# - Your domain should be $x \in [0, 10]$. *Hint: Use `np.linspace` to set a range of values for your functions.*
#
# Your function should return:
# - A list of $f(x)$ values
# - A list of $g(x)$ values.

# %%
def plottingFunction():
    x = np.arange(0,11)
    fx = x**2
    gx = x**(1/2)
    plt.figure(figsize = (10, 8))
    plt.plot(x, fx, color='blue', linestyle='dashed', marker='o')
    plt.plot(x, gx, color='red', linestyle='dotted', marker='s')
    plt.title('Functions Graph', fontsize = 15)
    plt.xlabel('X Axis', fontsize = 10)
    plt.ylabel('Y Axis', fontsize = 10)
    plt.legend(['f(x)', 'g(x)'])
    plt.grid()
    plt.show()
    return np.array([fx, gx])

plottingFunction()
# Out:
# array([[  0.        ,   1.        ,   4.        ,   9.        ,
#          16.        ,  25.        ,  36.        ,  49.        ,
#          64.        ,  81.        , 100.        ],
#        [  0.        ,   1.        ,   1.41421356,   1.73205081,
#           2.        ,   2.23606798,   2.44948974,   2.64575131,
#           2.82842712,   3.        ,   3.16227766]])

# %% [markdown]
# In a comment, describe how you move the legend from inside of your figure to upper-right region **outside** of your figure. Include the code as well.

# %%
# Add 'loc='center right', bbox_to_anchor=(1.15, 1)' to 'plt.legend(['f(x)', 'g(x)'])'
plt.legend(['f(x)', 'g(x)'], loc='center right', bbox_to_anchor=(1.15, 1))

# %% [markdown]
# In a comment, describe how you could add a **vertical and horizontal line** to your plot. Include the code as well.

# %%
# I would do plt.plot() and then use a repeating array with either the x or y value to create a straight line.
plt.plot(np.arange(0, 100), np.repeat(0, 100))
plt.plot(np.repeat(0, 100), np.arange(0, 100))

# %% [markdown]
# In a comment, describe how you could **change** the domain of $x$. Include the code as well.

# %%
# Use linspace instead of arange.
x = np.linspace(0, 15, 100)

# %% [markdown]
# In a comment, describe how you would **change the limits** of the `x` and `y` axis. Include the code as well.

# %%
# Use plt.xlim() and plt.ylim(). 
plt.xlim(0, 10)  
plt.ylim(0, 110)
# Out:
# (0.0, 110.0)

# %% [markdown]
# In a comment, describe how you could change your function to output the **sum** of the $f(x)$ and $g(x)$ values. Include the code as well.

# %%
# Add the two functions together and make a new plot. 
sum = fx + gx
plt.plot(x, sum, color='yellow', linestyle='dashdot', marker='*')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 2
#       1 # Add the two functions together and make a new plot.
# ----> 2 sum = fx + gx
#       3 plt.plot(x, sum, color='yellow', linestyle='dashdot', marker='*')
#
# NameError: name 'fx' is not defined

# %% [markdown]
# Make a **new function** (that has the same foundation as your first function in this question) but includes **all** the changes you described in your comments. Don't forget to call the function and show its output.

# %%
def updatedPlottingFunction():
    x = np.linspace(0, 15, 100)
    fx = x**2
    gx = x**(1/2)
    sum = fx + gx
    plt.figure(figsize = (10, 8))
    plt.plot(x, fx, color='blue', linestyle='dashed', marker='o')
    plt.plot(x, gx, color='red', linestyle='dotted', marker='s')
    plt.plot(np.arange(0, 100), np.repeat(0, 100))
    plt.plot(np.repeat(0, 100), np.arange(0, 100))
    plt.plot(x, sum, color='purple', linestyle='dashdot', marker='*')
    plt.title('Functions Graph', fontsize = 15)
    plt.xlabel('X Axis', fontsize = 10)
    plt.ylabel('Y Axis', fontsize = 10)
    plt.legend(['f(x)', 'g(x)', 'f(x) + g(x)'], loc='center right', bbox_to_anchor=(1.2, 1))
    plt.grid()
    plt.xlim(-1, 10)  
    plt.ylim(-10, 110)
    plt.show()
    return np.array([fx, gx, sum])

updatedPlottingFunction()
# Out:
# array([[0.00000000e+00, 2.29568411e-02, 9.18273646e-02, 2.06611570e-01,
#         3.67309458e-01, 5.73921028e-01, 8.26446281e-01, 1.12488522e+00,
#         1.46923783e+00, 1.85950413e+00, 2.29568411e+00, 2.77777778e+00,
#         3.30578512e+00, 3.87970615e+00, 4.49954086e+00, 5.16528926e+00,
#         5.87695133e+00, 6.63452709e+00, 7.43801653e+00, 8.28741965e+00,
#         9.18273646e+00, 1.01239669e+01, 1.11111111e+01, 1.21441690e+01,
#         1.32231405e+01, 1.43480257e+01, 1.55188246e+01, 1.67355372e+01,
#         1.79981635e+01, 1.93067034e+01, 2.06611570e+01, 2.20615243e+01,
#         2.35078053e+01, 2.50000000e+01, 2.65381084e+01, 2.81221304e+01,
#         2.97520661e+01, 3.14279155e+01, 3.31496786e+01, 3.49173554e+01,
#         3.67309458e+01, 3.85904500e+01, 4.04958678e+01, 4.24471993e+01,
#         4.44444444e+01, 4.64876033e+01, 4.85766758e+01, 5.07116621e+01,
#         5.28925620e+01, 5.51193756e+01, 5.73921028e+01, 5.97107438e+01,
#         6.20752984e+01, 6.44857668e+01, 6.69421488e+01, 6.94444444e+01,
#         7.19926538e+01, 7.45867769e+01, 7.72268136e+01, 7.99127640e+01,
#         8.26446281e+01, 8.54224059e+01, 8.82460973e+01, 9.11157025e+01,
#         9.40312213e+01, 9.69926538e+01, 1.00000000e+02, 1.03053260e+02,
#         1.06152433e+02, 1.09297521e+02, 1.12488522e+02, 1.15725436e+02,
#         1.19008264e+02, 1.22337006e+02, 1.25711662e+02, 1.29132231e+02,
#         1.32598714e+02, 1.36111111e+02, 1.39669421e+02, 1.43273646e+02,
#         1.46923783e+02, 1.50619835e+02, 1.54361800e+02, 1.58149679e+02,
#         1.61983471e+02, 1.65863177e+02, 1.69788797e+02, 1.73760331e+02,
#         1.77777778e+02, 1.81841139e+02, 1.85950413e+02, 1.90105601e+02,
#         1.94306703e+02, 1.98553719e+02, 2.02846648e+02, 2.07185491e+02,
#         2.11570248e+02, 2.16000918e+02, 2.20477502e+02, 2.25000000e+02],
#        [0.00000000e+00, 3.89249472e-01, 5.50481883e-01, 6.74199862e-01,
#         7.78498944e-01, 8.70388280e-01, 9.53462589e-01, 1.02985730e+00,
#         1.10096377e+00, 1.16774842e+00, 1.23091491e+00, 1.29099445e+00,
#         1.34839972e+00, 1.40345893e+00, 1.45643816e+00, 1.50755672e+00,
#         1.55699789e+00, 1.60491669e+00, 1.65144565e+00, 1.69669911e+00,
#         1.74077656e+00, 1.78376517e+00, 1.82574186e+00, 1.86677489e+00,
#         1.90692518e+00, 1.94624736e+00, 1.98479065e+00, 2.02259959e+00,
#         2.05971460e+00, 2.09617256e+00, 2.13200716e+00, 2.16724934e+00,
#         2.20192753e+00, 2.23606798e+00, 2.26969495e+00, 2.30283093e+00,
#         2.33549683e+00, 2.36771210e+00, 2.39949490e+00, 2.43086217e+00,
#         2.46182982e+00, 2.49241273e+00, 2.52262490e+00, 2.55247948e+00,
#         2.58198890e+00, 2.61116484e+00, 2.64001837e+00, 2.66855993e+00,
#         2.69679945e+00, 2.72474630e+00, 2.75240941e+00, 2.77979725e+00,
#         2.80691786e+00, 2.83377893e+00, 2.86038777e+00, 2.88675135e+00,
#         2.91287633e+00, 2.93876907e+00, 2.96443566e+00, 2.98988193e+00,
#         3.01511345e+00, 3.04013556e+00, 3.06495341e+00, 3.08957190e+00,
#         3.11399578e+00, 3.13822957e+00, 3.16227766e+00, 3.18614425e+00,
#         3.20983338e+00, 3.23334895e+00, 3.25669474e+00, 3.27987435e+00,
#         3.30289130e+00, 3.32574895e+00, 3.34845057e+00, 3.37099931e+00,
#         3.39339823e+00, 3.41565026e+00, 3.43775825e+00, 3.45972498e+00,
#         3.48155312e+00, 3.50324525e+00, 3.52480388e+00, 3.54623146e+00,
#         3.56753034e+00, 3.58870281e+00, 3.60975110e+00, 3.63067737e+00,
#         3.65148372e+00, 3.67217218e+00, 3.69274473e+00, 3.71320331e+00,
#         3.73354978e+00, 3.75378597e+00, 3.77391365e+00, 3.79393455e+00,
#         3.81385036e+00, 3.83366270e+00, 3.85337318e+00, 3.87298335e+00],
#        [0.00000000e+00, 4.12206313e-01, 6.42309247e-01, 8.80811433e-01,
#         1.14580840e+00, 1.44430931e+00, 1.77990887e+00, 2.15474252e+00,
#         2.57020160e+00, 3.02725255e+00, 3.52659902e+00, 4.06877223e+00,
#         4.65418485e+00, 5.28316508e+00, 5.95597903e+00, 6.67284598e+00,
#         7.43394922e+00, 8.23944378e+00, 9.08946218e+00, 9.98411876e+00,
#         1.09235130e+01, 1.19077321e+01, 1.29368530e+01, 1.40109439e+01,
#         1.51300657e+01, 1.62942731e+01, 1.75036153e+01, 1.87581368e+01,
#         2.00578781e+01, 2.14028760e+01, 2.27931642e+01, 2.42287737e+01,
#         2.57097329e+01, 2.72360680e+01, 2.88078033e+01, 3.04249613e+01,
#         3.20875629e+01, 3.37956276e+01, 3.55491735e+01, 3.73482175e+01,
#         3.91927756e+01, 4.10828627e+01, 4.30184927e+01, 4.49996787e+01,
#         4.70264333e+01, 4.90987681e+01, 5.12166942e+01, 5.33802220e+01,
#         5.55893614e+01, 5.78441219e+01, 6.01445123e+01, 6.24905410e+01,
#         6.48822163e+01, 6.73195457e+01, 6.98025365e+01, 7.23311958e+01,
#         7.49055301e+01, 7.75255459e+01, 8.01912493e+01, 8.29026459e+01,
#         8.56597415e+01, 8.84625414e+01, 9.13110507e+01, 9.42052744e+01,
#         9.71452171e+01, 1.00130883e+02, 1.03162278e+02, 1.06239404e+02,
#         1.09362267e+02, 1.12530870e+02, 1.15745216e+02, 1.19005311e+02,
#         1.22311156e+02, 1.25662755e+02, 1.29060113e+02, 1.32503231e+02,
#         1.35992113e+02, 1.39526761e+02, 1.43107180e+02, 1.46733371e+02,
#         1.50405336e+02, 1.54123080e+02, 1.57886604e+02, 1.61695910e+02,
#         1.65551001e+02, 1.69451880e+02, 1.73398548e+02, 1.77391008e+02,
#         1.81429261e+02, 1.85513311e+02, 1.89643158e+02, 1.93818805e+02,
#         1.98040253e+02, 2.02307505e+02, 2.06620562e+02, 2.10979426e+02,
#         2.15384098e+02, 2.19834581e+02, 2.24330875e+02, 2.28872983e+02]])

# %% [markdown]
# # 3 Introduction to Subplots
# Goal: Write a **module** (name it whatever you want, as long as it is professional) that contains two functions that do the following:
#
# Function 1:
# - Write a **function** that will plot two subplots side-by-side (horizontal).
# - The **left** subplot will be: $h(x) = \cos(x)$.
# - The **right** subplot will be $k(x) = \sin(x)$.
# - Include a title, axis labels and a domain of $x \in [0, 2 \pi]$ (this should NOT be hardcoded)
#
# Function 2:
# - Exactly the same as your first function, **EXCEPT** the subplots will be on top of each other (vertical).

# %% [markdown]
# Call your **first** function in the cell below.

# %%
import functionModule as fm
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 import functionModule as fm
#
# File ~\OneDrive\Desktop\ULAB\ulab_2024\homework9\functionModule.py:4
#       1 import matplotlib.pyplot as plt
#       2 import numpy as np
# ----> 4 sin = np.sin(x)
#       5 cos = np.cos(x)
#       7 def horizontalSubModules():
#
# NameError: name 'x' is not defined

# %% [markdown]
# Call your **second** function in the cell below.

# %%
fm.horizontalSubModules()

# %% [markdown]
# Change the domain of your function to be **twice** a large as the previous domain. Call both of your functions in the cell below with the new domain.

# %%
fm.verticalSubModules()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 fm.verticalSubModules()
#
# NameError: name 'fm' is not defined

# %% [markdown]
# # 4 Up to You!
# Now that you have been introduced to plotting data, functions and subplots, its up to you what to plot! Please refrain from importing other libraries besides `numpy` or `matplotlib`, if you do you need to explain WHY. Here are some ideas:
# - **Plot a 3D function**: https://matplotlib.org/stable/gallery/mplot3d/surface3d.html#sphx-glr-gallery-mplot3d-surface3d-py
# - **Plot a 3x3 grid of subplots**: https://matplotlib.org/stable/gallery/subplots_axes_and_figures/subplots_demo.html
# - **Plot an image with different colormaps:** https://matplotlib.org/stable/tutorials/images.html
# - **Something else that's cool!**
#
# Your idea must either come in the form of a **function** or a **module**, its up to you. **Bonus points** if its a function inside of a module.

# %%
import areaUnderCurve as ac

# %% [markdown]
# As a comment, put the link to the website that helped you with this problem (and what it taught you) or what you posted into ChatGPT for this question (and what it taught you).

# %% [markdown]
# As a comment, with 2-3 sentences describe what your code is doing.

# %%
ac.areaUnderCurve()

# %%
ac.areaUnderCurve()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 ac.areaUnderCurve()
#
# File ~\OneDrive\Desktop\ULAB\ulab_2024\homework9\areaUnderCurve.py:19, in areaUnderCurve()
#      16 section2 = np.linspace(0, pi*2, 1000)
#      18 fig, (ax1, ax2) = plt.subplots(1, 2, figsize = (10, 8))
# ---> 19 figsize.subplots_adjust(wspace = 0.5)
#      20 ax1.plot(x, equation, color='indigo', label='Equation')
#      21 ax2.plot(x2, equation2, color='navy', label='Equation 2')
#
# NameError: name 'figsize' is not defined

# %%
ac.areaUnderCurve()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 ac.areaUnderCurve()
#
# File ~\OneDrive\Desktop\ULAB\ulab_2024\homework9\areaUnderCurve.py:19, in areaUnderCurve()
#      16 section2 = np.linspace(0, pi*2, 1000)
#      18 fig, (ax1, ax2) = plt.subplots(1, 2, figsize = (10, 8))
# ---> 19 figsize.subplots_adjust(wspace = 0.5)
#      20 ax1.plot(x, equation, color='indigo', label='Equation')
#      21 ax2.plot(x2, equation2, color='navy', label='Equation 2')
#
# NameError: name 'figsize' is not defined

# %% [markdown]
# Your plots still need to include a title, axis labels and legends. If they don't you will get points marked off.

# %% [markdown]
# # 5 Proper Submission
# To recieve full credit for this assignment make sure you do the following:
#
# 1) Copy this homework assignment from the `ulab_2024` repository into **YOUR** local `homework9` branch.
#
# 2) Follow the tasks. Make sure to run all the cells so that **ALL** outputs are visible. You will get points taken off if your ouputs are not shown!
#
# 3) Add/commit/push this notebook to your remote `homework9` branch. Make sure to have NOTHING else in your branch (i.e. no previous homeworks or lecture notes).
#
# 4) Do the following:
# - Take a screenshot of moving **into or out** of your `homework9` brach, call it `hw9_branch`.
# - Take a screenshot of calling `ls` in your `homework9` branch, it should only contain items relevent to homework 9, call it `hw9_ls`.
# - Take a screenshot of adding this assignment to your local `homework9` branch, call it `hw9_add`.
# - Take a screenshot of committing this assignment to your local `homework9` branch, call it `hw9_commit`.
# - Take a screenshot of pushing this assignment to your remote `homework9` branch, call it `hw9_push`.
#
# 6) Include these screenshots in your `homework9` branch. Upload your `homework9` branch to Gradescope!
